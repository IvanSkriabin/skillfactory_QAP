# %%
"""
Входные данные:
напишите программу, которой на вход подается последовательность чисел через пробел, а также 
запрашивается у пользователя любое число (target).
Далее программа работает по следующему алгоритму:
1. Преобразовать последовательность в список (Python list);
2. Сортировка списка по возрастанию элементов в нем;
3. Устанавливается номер позиции элемента, который меньше введенного пользователем числа, а 
следующий за ним больше или равен этому числу;
4. Реализовать функцию binary search.
Вывод (результат работы программы):
1. Индекс элемента (номер позиции элемента) < target;
2. Индекс элемента (номер позиции элемента) >= target;
3. Вывести сообщение, если есть числа, которые могут не соответствовать заданному условию.
Примечание!
Так как в задании ничего не сказано о том,
должны ли быть индексы из оригинального или из отсортированного списка, то
будем выводить индексы из отсортированного списка
"""


def insert_sort(array: list) -> list:
    for i in range(len(array)):
        current = array[i]
        indx = i
        while indx > 0 and array[indx - 1] > current:
            array[indx] = array[indx - 1]
            indx -= 1
        array[indx] = current
    return array


# применим алгорит двоичного поиска
def binary_search(array: list, target: int):
    low = 0
    high = len(array) - 1
    # Если искомого элемента (target) нет в спиксе, ищем его в словаре (nearest) с ближайщими элементами
    nearest = {}  # индекс: разность между искомым и текущим элементами

    while low <= high:
        mid = (low + high) // 2
        if target == array[mid]:
            print(f"Индекс элемента меньшего искомого {mid - 1}\
                \nИндекс искомого элемента {mid}")
            return True
        elif target < array[mid]:
            nearest[mid] = (target - array[mid])
            high = mid - 1
        else:
            nearest[mid] = (target - array[mid])
            low = mid + 1
    nearest_indexes(nearest)


# Если искомого элемента (target) нет в списке, то мы ищем ближайшее
def nearest_indexes(pairs: dict):
    keys = list(pairs.keys())
    low = keys[-2]
    hight = keys[-1]
    print(f"Искомый элемент не содержится в списке, но\
        \nИндекс элемента меньше искомого {low}\
        \nИндекс элемента больше искомого {hight}")


try:
    data = [int(i) for i in input("Введите числа через пробел:\n").split()]
    n = int(input("Введите искомое число:\n"))
except TypeError:
    print("Вводимая строка должна состоять только из чисел") # проверка, что введены именно числа


data = insert_sort(data)
if n == data[0]:
    print("Искомый элемент является минимальным в списке")
elif n < data[0]:
    print("Искомый элемент меньше минимального в списке")
elif n == data[-1]:
    print("Искомый элемент является максимальным в списке")
elif n > data[-1]:
    print("Искомый элемент больше максимального в списке")
else:
    binary_search(data, n)
# Out:
# Введите числа через пробел:
# 2 7 6 8 10 15 25
# Введите искомое число:
# 13
# Искомый элемент не содержится в списке, но
# Индекс элемента меньше искомого 5
# Индекс элемента больше искомого 4
